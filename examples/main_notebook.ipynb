# %%
from subnotebook import open_nb, display_nb

# %%
nb = open_nb('sub_notebook.ipynb')

# %%
ab, ba, slider, output = nb.run(a='c', b='d')

# %%
print(ab, ba)

# %%
slider

# %%
output

# %%
display_nb('widget_notebook.ipynb')
